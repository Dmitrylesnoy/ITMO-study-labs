# %%
def func(x):
    return 3*x**3 + 5*x**2 + 3*x-6

# %%
x=1.
i=0
while i<=10:
    print(f"{i}, {x:.2f} : {func(x):.4f}")
    i+=1
    x+=0.1
# Out:
# 0, 1.00 : 5.0000
# 1, 1.10 : 7.3430
# 2, 1.20 : 9.9840
# 3, 1.30 : 12.9410
# 4, 1.40 : 16.2320
# 5, 1.50 : 19.8750
# 6, 1.60 : 23.8880
# 7, 1.70 : 28.2890
# 8, 1.80 : 33.0960
# 9, 1.90 : 38.3270
# 10, 2.00 : 44.0000

# %%
sum([6.1354,
8.6251,
11.4219,
14.5436,
18.0084,
21.8341,
26.0389,
30.6406,
35.6574,
44.1071]
)
# Out:
# 217.01250000000002

# %%
sum([7.3430,
9.9840,
12.9410,
16.2320,
19.8750,
23.8880,
28.2890,
33.0960,
38.3270,
(44+5)/2
])
# Out:
# 214.475

# %%
x=1
i=0
I=0
while i<=10:
    y = func(x)
    print(f"{i}, {x:.2f} : {y:.4f}")
    if i==0 or i==10:
        I+=y
    else:
        if i%2==0:
            I+=2*y
        else:
            I+=4*y
    i+=1
    x+=0.1
print(I*0.1/3)
# Out:
# 0, 1.00 : 5.0000
# 1, 1.10 : 7.3430
# 2, 1.20 : 9.9840
# 3, 1.30 : 12.9410
# 4, 1.40 : 16.2320
# 5, 1.50 : 19.8750
# 6, 1.60 : 23.8880
# 7, 1.70 : 28.2890
# 8, 1.80 : 33.0960
# 9, 1.90 : 38.3270
# 10, 2.00 : 44.0000
# 21.416666666666686

# %%
x=1
i=0
s=0
while i<=6:
    print(f"{i}, {x:.2f} : {func(x):.4f}")
    s+=func(x)
    i+=1
    x+= 1/6
print(s)
print(s/840)
# Out:
# 0, 1.00 : 5.0000
# 1, 1.17 : 9.0694
# 2, 1.33 : 14.0000
# 3, 1.50 : 19.8750
# 4, 1.67 : 26.7778
# 5, 1.83 : 34.7917
# 6, 2.00 : 44.0000
# 153.51388888888897
# 0.18275462962962974

# %%
1*(41*func(1)+216*func(1+1/6)+27*func(1+2/6)+272*func(1+3/6)+27*func(1+4/6)+216*func(1+5/6)+41*func(2))
# Out:
# 17990.0

# %% [markdown]
# точное 21,41666667
# котса 21,41667
# прямугольников
# трапеций 21,4475
# симпсона 21,41667

# %%
ideal=21.416666666666666666666666666666
curr=1/840 * 17990
print(f"{abs(ideal-curr)/ideal:.15f}")
# Out:
# 0.000000000000000
